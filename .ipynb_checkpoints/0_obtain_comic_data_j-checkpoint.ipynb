# %% [markdown]
# # 0. Web APIを用いたマンガ雑誌データの取得
#
# 　[文化庁メディア芸術データベース　マンガ分野　WebAPI](https://mediaarts-db.bunka.go.jp/webapi_proto_documents.pdf)を用いて，分析に必要なデータを入手します．なお，python3を使ったweb APIの利用については，[Python3でjsonを返却するwebAPIにアクセスして結果を出力するまで](http://qiita.com/sakura1116/items/4a11a9f7db9f535397fa)を参考にさせて頂きました．
#
# ## 環境構築
#
# ```bash
# conda env create -f env.yml
# ```
#
# ## 準備

# %%
import json
import urllib.request
from time import sleep

# %% [markdown]
# ## 雑誌巻号検索結果の取得
#
# 　以下の関数`search_magazine()`を使って，週刊少年ジャンプの雑誌巻号情報を検索し，結果を変数`magazines`に保存します．ここで取得したユニークIDは，次節の「雑誌巻号情報の取得」に必要になります．

# %%
def search_magazine(key='JUMPrgl', n_pages=25):
    """
    「ユニークID」「雑誌巻号ID」あるいは「雑誌コード」にkey含む雑誌を，
    n_pages分取得する関数です．
    """
    
    url = 'https://mediaarts-db.bunka.go.jp/mg/api/v1/results_magazines?id=' + \
        key + '&page='
    magazines = []
    
    for i in range(1, n_pages):
        response = urllib.request.urlopen(url + str(i))
        content = json.loads(response.read().decode('utf8'))
        magazines.extend(content['results'])
    return magazines

# %% [markdown]
# 　WebAPIでは，パラメータ`id`で「ユニークID」「雑誌巻号ID」あるいは「雑誌コード」を，`page`で検索結果の取得ページ番号（1ページあたり100件，デフォルトは1）を指定することができます．ここで，週刊少年ジャンプは「雑誌巻号ID」に`JUMPrgl`を含むため，`id=JUMPrgl`を指定します．また，週刊少年ジャンプの検索結果は合計24ページ（2320件）あるため，`page`に1から24を順次指定する必要があります．
# 詳細は[WebAPI仕様](https://mediaarts-db.bunka.go.jp/webapi_proto_documents.pdf)をご参照ください．
#
# 　なお，2017年3月31日より文化庁メディア芸術データベースのURLが変更されたため，[WebAPI仕様](https://mediaarts-db.bunka.go.jp/webapi_proto_documents.pdf)に記載のリクエストURL（`https://mediaarts-db.jp/mg/api/v1/results_magazines`）ではなく，新しいURL（`https://mediaarts-db.bunka.go.jp/mg/api/v1/results_magazines`）を使用する必要があることにご注意ください．

# %%
magazines = search_magazine()

# %%
len(magazines)
# Out:
# 2320

# %%
magazines[0]
# Out:
# {'date_indication': '1969/11/03',
#  'id': 323270,
#  'magazine_id': 'JUMPrgl19691103',
#  'name': '週刊少年ジャンプ',
#  'number_assist': '',
#  'number_indication': '20',
#  'owner_kawasaki': 0,
#  'owner_kikuyo': 0,
#  'owner_kyoto': 1,
#  'owner_meiji': 0,
#  'owner_ndl': 0,
#  'owner_osaka': 0,
#  'publisher': '集英社',
#  'vol_num_totalval': '2巻24号(通巻35)'}

# %%
magazines[-1]
# Out:
# {'date_indication': '2016/12/12',
#  'id': 475979,
#  'magazine_id': 'JUMPrgl20161212',
#  'name': '週刊少年ジャンプ',
#  'number_assist': '',
#  'number_indication': '52',
#  'owner_kawasaki': 0,
#  'owner_kikuyo': 0,
#  'owner_kyoto': 0,
#  'owner_meiji': 0,
#  'owner_ndl': 1,
#  'owner_osaka': 0,
#  'publisher': '',
#  'vol_num_totalval': '49巻48号(通巻2389)'}

# %% [markdown]
# ## 雑誌巻号情報の取得
#
# 　以下の関数`extract_data()`で必要な目次情報を抽出し，`save_data()`で目次情報を保存します．

# %%
def extract_data(content):
    """
    contentに含まれる目次情報を取得する関数です．
    - year: 発行年
    - no: 号数
    - title: 作品名
    - author: 著者
    - color: カラーか否か
    - pages: 掲載ページ数
    - start_page: 作品のスタートページ
    - best: 巻頭から数えた掲載順
    - worst: 巻末から数えた掲載順
    """
    
    # マンガ作品のみ抽出します．
    comics = [comic for comic in content['contents'] 
             if comic['category']=='マンガ作品'] 
    data = []
    year = int(content['basics']['date_indication'][:4])
    
    # 号数が記載されていない場合があるので，例外処理が必要です．
    try:
        no = int(content['basics']['number_indication'])
    except ValueError:
        no = content['basics']['number_indication']
    
    for comic in comics:
        title= comic['work']
        if not title:
            continue
            
        # ページ数が記載されていない作品があるので，例外処理が必要です．
        # 特に理由はないですが，無記載の作品は10ページとして処理を進めます．
        try:
            pages = int(comic['work_pages'])
        except ValueError:
            pages = 10

        # 「いぬまるだしっ」等，1週に複数話掲載されている作品に対応するため
        # data中にすでにtitleが含まれる場合は，新規datumとして登録せずに，
        # 既存のdatumのページ数のみ加算します．
        if len(data) > 0 and title in [datum['title'] for datum in data]:
            data[[datum['title'] for datum in 
                  data].index(title)]['pages'] += pages
        else:
            data.append({
                'year': year,
                'no': no,
                'title': comic['work'],
                'author': comic['author'],
                'subtitle': comic['subtitle'],
                'color': comic['note'].count('カラー'),
                'pages': int(comic['work_pages']),
                'start_pages': int(comic['start_page'])
            })

    # 企画物のミニマンガを除外するため，合計5ページ以下のdatumはリストから除外します．
    filterd_data = [datum for datum in data if datum['pages'] > 5]
    for n, datum in enumerate(filterd_data):
        datum['best'] = n + 1
        datum['worst'] = len(filterd_data) - n
        
    return filterd_data

# %% [markdown]
# 　泥臭い話ですが，一部のギャグ漫画の扱いに苦労しました．例えば，「[いぬまるだしっ](https://mediaarts-db.bunka.go.jp/mg/magazine_works/545?ids%5B%5D=545)」は，基本的に一週間に2話ずつ掲載していましたが，データベースでは各話が別々の行に記載されています．これらを１つの作品として見なす必要があるので，当該`comic`の`title`が`data`中にある場合は，別`datum`として`data`に追加せず，既存の`datum`の`pages`を加算する処理を行っています．また，例えば「[ピューと吹く!ジャガー](https://mediaarts-db.bunka.go.jp/mg/comic_works/83870)」は，その人気に関係なく（実際めちゃくちゃ面白かったです），連載中は常に雑誌の最後に掲載されていました．これを外れ値として除外するかどうかで悩みましたが，結局残すことにしました．

# %%
def save_data(magazines, offset=0, file_name='data/wj-api.json'):
    """
    magazinesに含まれる全てのmagazineについて，先頭からoffset以降の巻号の
    目次情報を取得し，file_nameに保存する関数です．
    """
    
    url = 'https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id='
    
    #　ファイル先頭行
    if offset == 0:
        with open(file_name, 'w') as f:
            f.write('[\n')
        
    with open(file_name, 'a') as f:
        
        # magazines中のmagazine毎にWeb APIを叩きます．
        for m, magazine in enumerate(magazines[offset:]):
            response = urllib.request.urlopen(url + str(magazine['id']),
                                              timeout=30)
            content = json.loads(response.read().decode('utf8'))
            
            # 前記の関数extract_data()で，必要な情報を抽出します．
            comics = extract_data(content)
            print('{0:4d}/{1}: Extracted data from {2}'.\
                  format(m + offset, len(magazines), url + str(magazine['id'])))
            
            # comics中の各comicについて，file_nameに情報を保存します．
            for n, comic in enumerate(comics):
                
                # ファイル先頭以外の，magazineの最初のcomicの場合は，
                # まず',\n'を追記．
                if m + offset > 0 and n == 0:
                    f.write(',\n')
                
                json.dump(comic, f, ensure_ascii=False)
                
                # 最後のcomic以外は',\n'を追記．
                if not n == len(comics) - 1:
                    f.write(',\n')
            print('{0:9}: Saved data to {1}'.format(' ', file_name))
            
            # サーバへの負荷を抑えるため，必ず一時停止します．
            sleep(3)
            
    # ファイル最終行
    with open(file_name, 'a') as f:

        
        f.write(']')

# %% [markdown]
# 　タイムアウトに柔軟に対応するため，目次情報を一括処理せず，無理やり逐次処理にしています．また，サーバに負荷をかけないよう，`sleep()`で一時停止していることにご注意ください．
#
# 　なお，2017年3月31日より文化庁メディア芸術データベースのURLが変更されたため，[WebAPI仕様](https://mediaarts-db.bunka.go.jp/webapi_proto_documents.pdf)に記載のリクエストURL（`https://mediaarts-db.jp/mg/api/v1/magazine`）ではなく，新しいURL（`https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine`）を使用する必要があることにご注意ください．
#
#  　以下を実行し，`wj-api.json`にデータを保存します．

# %%
save_data(magazines)
# Out:
#    0/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323270
#          : Saved data to data/wj-api.json
#    1/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323269
#          : Saved data to data/wj-api.json
#    2/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323268
#          : Saved data to data/wj-api.json
#    3/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323267
#          : Saved data to data/wj-api.json
#    4/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323266
#          : Saved data to data/wj-api.json
#    5/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323265
#          : Saved data to data/wj-api.json
#    6/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323264
#          : Saved data to data/wj-api.json
#    7/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323263
#          : Saved data to data/wj-api.json
#    8/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323262
#          : Saved data to data/wj-api.json
#    9/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323261
#          : Saved data to data/wj-api.json
#   10/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323260
#          : Saved data to data/wj-api.json
#   11/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323259
#          : Saved data to data/wj-api.json
#   12/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323258
#          : Saved data to data/wj-api.json
#   13/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323257
#          : Saved data to data/wj-api.json
#   14/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323256
#          : Saved data to data/wj-api.json
#   15/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323255
#          : Saved data to data/wj-api.json
#   16/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323254
#          : Saved data to data/wj-api.json
#   17/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323253
#          : Saved data to data/wj-api.json
#   18/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323252
#          : Saved data to data/wj-api.json
#   19/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323251
#          : Saved data to data/wj-api.json
#   20/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396527
#          : Saved data to data/wj-api.json
#   21/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323250
#          : Saved data to data/wj-api.json
#   22/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323249
#          : Saved data to data/wj-api.json
#   23/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323248
#          : Saved data to data/wj-api.json
#   24/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323247
#          : Saved data to data/wj-api.json
#   25/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323246
#          : Saved data to data/wj-api.json
#   26/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323245
#          : Saved data to data/wj-api.json
#   27/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323244
#          : Saved data to data/wj-api.json
#   28/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323243
#          : Saved data to data/wj-api.json
#   29/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323242
#          : Saved data to data/wj-api.json
#   30/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323241
#          : Saved data to data/wj-api.json
#   31/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396528
#          : Saved data to data/wj-api.json
#   32/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396529
#          : Saved data to data/wj-api.json
#   33/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323240
#          : Saved data to data/wj-api.json
#   34/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323239
#          : Saved data to data/wj-api.json
#   35/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323238
#          : Saved data to data/wj-api.json
#   36/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323237
#          : Saved data to data/wj-api.json
#   37/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396530
#          : Saved data to data/wj-api.json
#   38/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323236
#          : Saved data to data/wj-api.json
#   39/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323235
#          : Saved data to data/wj-api.json
#   40/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323234
#          : Saved data to data/wj-api.json
#   41/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323233
#          : Saved data to data/wj-api.json
#   42/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323232
#          : Saved data to data/wj-api.json
#   43/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323231
#          : Saved data to data/wj-api.json
#   44/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323230
#          : Saved data to data/wj-api.json
#   45/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396531
#          : Saved data to data/wj-api.json
#   46/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396532
#          : Saved data to data/wj-api.json
#   47/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323229
#          : Saved data to data/wj-api.json
#   48/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323228
#          : Saved data to data/wj-api.json
#   49/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323227
#          : Saved data to data/wj-api.json
#   50/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323226
#          : Saved data to data/wj-api.json
#   51/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323225
#          : Saved data to data/wj-api.json
#   52/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321743
#          : Saved data to data/wj-api.json
#   53/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322428
#          : Saved data to data/wj-api.json
#   54/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322285
#          : Saved data to data/wj-api.json
#   55/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322147
#          : Saved data to data/wj-api.json
#   56/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321672
#          : Saved data to data/wj-api.json
#   57/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321517
#          : Saved data to data/wj-api.json
#   58/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323027
#          : Saved data to data/wj-api.json
#   59/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322994
#          : Saved data to data/wj-api.json
#   60/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323224
#          : Saved data to data/wj-api.json
#   61/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323223
#          : Saved data to data/wj-api.json
#   62/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323222
#          : Saved data to data/wj-api.json
#   63/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323220
#          : Saved data to data/wj-api.json
#   64/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323219
#          : Saved data to data/wj-api.json
#   65/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323218
#          : Saved data to data/wj-api.json
#   66/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323217
#          : Saved data to data/wj-api.json
#   67/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323216
#          : Saved data to data/wj-api.json
#   68/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323215
#          : Saved data to data/wj-api.json
#   69/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323214
#          : Saved data to data/wj-api.json
#   70/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323213
#          : Saved data to data/wj-api.json
#   71/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323212
#          : Saved data to data/wj-api.json
#   72/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323211
#          : Saved data to data/wj-api.json
#   73/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323210
#          : Saved data to data/wj-api.json
#   74/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323209
#          : Saved data to data/wj-api.json
#   75/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323208
#          : Saved data to data/wj-api.json
#   76/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323207
#          : Saved data to data/wj-api.json
#   77/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323206
#          : Saved data to data/wj-api.json
#   78/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323205
#          : Saved data to data/wj-api.json
#   79/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323204
#          : Saved data to data/wj-api.json
#   80/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323203
#          : Saved data to data/wj-api.json
#   81/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323202
#          : Saved data to data/wj-api.json
#   82/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323201
#          : Saved data to data/wj-api.json
#   83/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323200
#          : Saved data to data/wj-api.json
#   84/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323199
#          : Saved data to data/wj-api.json
#   85/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323198
#          : Saved data to data/wj-api.json
#   86/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323197
#          : Saved data to data/wj-api.json
#   87/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323196
#          : Saved data to data/wj-api.json
#   88/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323195
#          : Saved data to data/wj-api.json
#   89/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323194
#          : Saved data to data/wj-api.json
#   90/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323193
#          : Saved data to data/wj-api.json
#   91/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323192
#          : Saved data to data/wj-api.json
#   92/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323191
#          : Saved data to data/wj-api.json
#   93/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323190
#          : Saved data to data/wj-api.json
#   94/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323189
#          : Saved data to data/wj-api.json
#   95/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323188
#          : Saved data to data/wj-api.json
#   96/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323187
#          : Saved data to data/wj-api.json
#   97/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323186
#          : Saved data to data/wj-api.json
#   98/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323185
#          : Saved data to data/wj-api.json
#   99/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323184
#          : Saved data to data/wj-api.json
#  100/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323183
#          : Saved data to data/wj-api.json
#  101/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323182
#          : Saved data to data/wj-api.json
#  102/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323181
#          : Saved data to data/wj-api.json
#  103/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323180
#          : Saved data to data/wj-api.json
#  104/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323179
#          : Saved data to data/wj-api.json
#  105/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323178
#          : Saved data to data/wj-api.json
#  106/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323177
#          : Saved data to data/wj-api.json
#  107/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323176
#          : Saved data to data/wj-api.json
#  108/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323175
#          : Saved data to data/wj-api.json
#  109/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323174
#          : Saved data to data/wj-api.json
#  110/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323173
#          : Saved data to data/wj-api.json
#  111/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323172
#          : Saved data to data/wj-api.json
#  112/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323171
#          : Saved data to data/wj-api.json
#  113/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323170
#          : Saved data to data/wj-api.json
#  114/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323169
#          : Saved data to data/wj-api.json
#  115/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323168
#          : Saved data to data/wj-api.json
#  116/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323167
#          : Saved data to data/wj-api.json
#  117/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323166
#          : Saved data to data/wj-api.json
#  118/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323165
#          : Saved data to data/wj-api.json
#  119/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323164
#          : Saved data to data/wj-api.json
#  120/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323163
#          : Saved data to data/wj-api.json
#  121/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323162
#          : Saved data to data/wj-api.json
#  122/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323161
#          : Saved data to data/wj-api.json
#  123/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323160
#          : Saved data to data/wj-api.json
#  124/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323159
#          : Saved data to data/wj-api.json
#  125/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323158
#          : Saved data to data/wj-api.json
#  126/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323157
#          : Saved data to data/wj-api.json
#  127/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323156
#          : Saved data to data/wj-api.json
#  128/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323155
#          : Saved data to data/wj-api.json
#  129/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323154
#          : Saved data to data/wj-api.json
#  130/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323153
#          : Saved data to data/wj-api.json
#  131/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323152
#          : Saved data to data/wj-api.json
#  132/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323151
#          : Saved data to data/wj-api.json
#  133/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323150
#          : Saved data to data/wj-api.json
#  134/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323149
#          : Saved data to data/wj-api.json
#  135/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323148
#          : Saved data to data/wj-api.json
#  136/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323147
#          : Saved data to data/wj-api.json
#  137/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323146
#          : Saved data to data/wj-api.json
#  138/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323145
#          : Saved data to data/wj-api.json
#  139/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323144
#          : Saved data to data/wj-api.json
#  140/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323143
#          : Saved data to data/wj-api.json
#  141/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323142
#          : Saved data to data/wj-api.json
#  142/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323141
#          : Saved data to data/wj-api.json
#  143/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323140
#          : Saved data to data/wj-api.json
#  144/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323139
#          : Saved data to data/wj-api.json
#  145/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323138
#          : Saved data to data/wj-api.json
#  146/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323137
#          : Saved data to data/wj-api.json
#  147/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323136
#          : Saved data to data/wj-api.json
#  148/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323135
#          : Saved data to data/wj-api.json
#  149/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323134
#          : Saved data to data/wj-api.json
#  150/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323133
#          : Saved data to data/wj-api.json
#  151/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323132
#          : Saved data to data/wj-api.json
#  152/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323131
#          : Saved data to data/wj-api.json
#  153/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323130
#          : Saved data to data/wj-api.json
#  154/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323129
#          : Saved data to data/wj-api.json
#  155/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323128
#          : Saved data to data/wj-api.json
#  156/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323127
#          : Saved data to data/wj-api.json
#  157/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323126
#          : Saved data to data/wj-api.json
#  158/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323125
#          : Saved data to data/wj-api.json
#  159/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323124
#          : Saved data to data/wj-api.json
#  160/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323123
#          : Saved data to data/wj-api.json
#  161/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323122
#          : Saved data to data/wj-api.json
#  162/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323121
#          : Saved data to data/wj-api.json
#  163/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323120
#          : Saved data to data/wj-api.json
#  164/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323119
#          : Saved data to data/wj-api.json
#  165/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323118
#          : Saved data to data/wj-api.json
#  166/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323117
#          : Saved data to data/wj-api.json
#  167/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323116
#          : Saved data to data/wj-api.json
#  168/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323115
#          : Saved data to data/wj-api.json
#  169/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323114
#          : Saved data to data/wj-api.json
#  170/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323113
#          : Saved data to data/wj-api.json
#  171/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323112
#          : Saved data to data/wj-api.json
#  172/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323111
#          : Saved data to data/wj-api.json
#  173/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323110
#          : Saved data to data/wj-api.json
#  174/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323109
#          : Saved data to data/wj-api.json
#  175/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323108
#          : Saved data to data/wj-api.json
#  176/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323107
#          : Saved data to data/wj-api.json
#  177/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323106
#          : Saved data to data/wj-api.json
#  178/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323105
#          : Saved data to data/wj-api.json
#  179/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323104
#          : Saved data to data/wj-api.json
#  180/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323103
#          : Saved data to data/wj-api.json
#  181/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323102
#          : Saved data to data/wj-api.json
#  182/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323101
#          : Saved data to data/wj-api.json
#  183/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323100
#          : Saved data to data/wj-api.json
#  184/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323099
#          : Saved data to data/wj-api.json
#  185/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323098
#          : Saved data to data/wj-api.json
#  186/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323097
#          : Saved data to data/wj-api.json
#  187/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323096
#          : Saved data to data/wj-api.json
#  188/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323095
#          : Saved data to data/wj-api.json
#  189/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323094
#          : Saved data to data/wj-api.json
#  190/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323093
#          : Saved data to data/wj-api.json
#  191/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323092
#          : Saved data to data/wj-api.json
#  192/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323091
#          : Saved data to data/wj-api.json
#  193/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323089
#          : Saved data to data/wj-api.json
#  194/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323088
#          : Saved data to data/wj-api.json
#  195/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323087
#          : Saved data to data/wj-api.json
#  196/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323086
#          : Saved data to data/wj-api.json
#  197/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323085
#          : Saved data to data/wj-api.json
#  198/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323084
#          : Saved data to data/wj-api.json
#  199/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323083
#          : Saved data to data/wj-api.json
#  200/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323082
#          : Saved data to data/wj-api.json
#  201/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323081
#          : Saved data to data/wj-api.json
#  202/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323080
#          : Saved data to data/wj-api.json
#  203/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323079
#          : Saved data to data/wj-api.json
#  204/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323078
#          : Saved data to data/wj-api.json
#  205/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323077
#          : Saved data to data/wj-api.json
#  206/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323076
#          : Saved data to data/wj-api.json
#  207/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323075
#          : Saved data to data/wj-api.json
#  208/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323074
#          : Saved data to data/wj-api.json
#  209/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323073
#          : Saved data to data/wj-api.json
#  210/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323072
#          : Saved data to data/wj-api.json
#  211/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323071
#          : Saved data to data/wj-api.json
#  212/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323070
#          : Saved data to data/wj-api.json
#  213/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323069
#          : Saved data to data/wj-api.json
#  214/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323068
#          : Saved data to data/wj-api.json
#  215/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323067
#          : Saved data to data/wj-api.json
#  216/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323066
#          : Saved data to data/wj-api.json
#  217/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323065
#          : Saved data to data/wj-api.json
#  218/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323064
#          : Saved data to data/wj-api.json
#  219/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323063
#          : Saved data to data/wj-api.json
#  220/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323062
#          : Saved data to data/wj-api.json
#  221/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323061
#          : Saved data to data/wj-api.json
#  222/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323060
#          : Saved data to data/wj-api.json
#  223/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323059
#          : Saved data to data/wj-api.json
#  224/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323058
#          : Saved data to data/wj-api.json
#  225/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323057
#          : Saved data to data/wj-api.json
#  226/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323056
#          : Saved data to data/wj-api.json
#  227/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323055
#          : Saved data to data/wj-api.json
#  228/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323054
#          : Saved data to data/wj-api.json
#  229/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323053
#          : Saved data to data/wj-api.json
#  230/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323052
#          : Saved data to data/wj-api.json
#  231/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323051
#          : Saved data to data/wj-api.json
#  232/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323050
#          : Saved data to data/wj-api.json
#  233/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323049
#          : Saved data to data/wj-api.json
#  234/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323048
#          : Saved data to data/wj-api.json
#  235/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323047
#          : Saved data to data/wj-api.json
#  236/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323046
#          : Saved data to data/wj-api.json
#  237/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323045
#          : Saved data to data/wj-api.json
#  238/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323044
#          : Saved data to data/wj-api.json
#  239/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323043
#          : Saved data to data/wj-api.json
#  240/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323042
#          : Saved data to data/wj-api.json
#  241/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323041
#          : Saved data to data/wj-api.json
#  242/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323040
#          : Saved data to data/wj-api.json
#  243/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323039
#          : Saved data to data/wj-api.json
#  244/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323038
#          : Saved data to data/wj-api.json
#  245/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323037
#          : Saved data to data/wj-api.json
#  246/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323036
#          : Saved data to data/wj-api.json
#  247/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323035
#          : Saved data to data/wj-api.json
#  248/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323034
#          : Saved data to data/wj-api.json
#  249/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323033
#          : Saved data to data/wj-api.json
#  250/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323032
#          : Saved data to data/wj-api.json
#  251/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323031
#          : Saved data to data/wj-api.json
#  252/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323030
#          : Saved data to data/wj-api.json
#  253/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323029
#          : Saved data to data/wj-api.json
#  254/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323028
#          : Saved data to data/wj-api.json
#  255/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323026
#          : Saved data to data/wj-api.json
#  256/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323025
#          : Saved data to data/wj-api.json
#  257/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323024
#          : Saved data to data/wj-api.json
#  258/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323023
#          : Saved data to data/wj-api.json
#  259/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323022
#          : Saved data to data/wj-api.json
#  260/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323021
#          : Saved data to data/wj-api.json
#  261/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323020
#          : Saved data to data/wj-api.json
#  262/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323019
#          : Saved data to data/wj-api.json
#  263/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323018
#          : Saved data to data/wj-api.json
#  264/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323017
#          : Saved data to data/wj-api.json
#  265/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323015
#          : Saved data to data/wj-api.json
#  266/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323014
#          : Saved data to data/wj-api.json
#  267/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323013
#          : Saved data to data/wj-api.json
#  268/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323012
#          : Saved data to data/wj-api.json
#  269/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323011
#          : Saved data to data/wj-api.json
#  270/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323010
#          : Saved data to data/wj-api.json
#  271/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323009
#          : Saved data to data/wj-api.json
#  272/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323008
#          : Saved data to data/wj-api.json
#  273/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323007
#          : Saved data to data/wj-api.json
#  274/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323006
#          : Saved data to data/wj-api.json
#  275/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323005
#          : Saved data to data/wj-api.json
#  276/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323004
#          : Saved data to data/wj-api.json
#  277/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323003
#          : Saved data to data/wj-api.json
#  278/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323002
#          : Saved data to data/wj-api.json
#  279/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323001
#          : Saved data to data/wj-api.json
#  280/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=323000
#          : Saved data to data/wj-api.json
#  281/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322999
#          : Saved data to data/wj-api.json
#  282/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322998
#          : Saved data to data/wj-api.json
#  283/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322997
#          : Saved data to data/wj-api.json
#  284/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322996
#          : Saved data to data/wj-api.json
#  285/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322995
#          : Saved data to data/wj-api.json
#  286/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322993
#          : Saved data to data/wj-api.json
#  287/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322992
#          : Saved data to data/wj-api.json
#  288/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322991
#          : Saved data to data/wj-api.json
#  289/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322990
#          : Saved data to data/wj-api.json
#  290/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322989
#          : Saved data to data/wj-api.json
#  291/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322988
#          : Saved data to data/wj-api.json
#  292/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322987
#          : Saved data to data/wj-api.json
#  293/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322986
#          : Saved data to data/wj-api.json
#  294/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322985
#          : Saved data to data/wj-api.json
#  295/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322984
#          : Saved data to data/wj-api.json
#  296/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322983
#          : Saved data to data/wj-api.json
#  297/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322982
#          : Saved data to data/wj-api.json
#  298/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322981
#          : Saved data to data/wj-api.json
#  299/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322980
#          : Saved data to data/wj-api.json
#  300/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322979
#          : Saved data to data/wj-api.json
#  301/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322978
#          : Saved data to data/wj-api.json
#  302/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322977
#          : Saved data to data/wj-api.json
#  303/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322976
#          : Saved data to data/wj-api.json
#  304/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322975
#          : Saved data to data/wj-api.json
#  305/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322974
#          : Saved data to data/wj-api.json
#  306/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=396533
#          : Saved data to data/wj-api.json
#  307/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322973
#          : Saved data to data/wj-api.json
#  308/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322972
#          : Saved data to data/wj-api.json
#  309/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322971
#          : Saved data to data/wj-api.json
#  310/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322970
#          : Saved data to data/wj-api.json
#  311/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322969
#          : Saved data to data/wj-api.json
#  312/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322968
#          : Saved data to data/wj-api.json
#  313/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322967
#          : Saved data to data/wj-api.json
#  314/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322966
#          : Saved data to data/wj-api.json
#  315/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322965
#          : Saved data to data/wj-api.json
#  316/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322964
#          : Saved data to data/wj-api.json
#  317/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322963
#          : Saved data to data/wj-api.json
#  318/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322962
#          : Saved data to data/wj-api.json
#  319/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322961
#          : Saved data to data/wj-api.json
#  320/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322960
#          : Saved data to data/wj-api.json
#  321/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322959
#          : Saved data to data/wj-api.json
#  322/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322958
#          : Saved data to data/wj-api.json
#  323/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322957
#          : Saved data to data/wj-api.json
#  324/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322956
#          : Saved data to data/wj-api.json
#  325/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322955
#          : Saved data to data/wj-api.json
#  326/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322916
#          : Saved data to data/wj-api.json
#  327/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322954
#          : Saved data to data/wj-api.json
#  328/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322953
#          : Saved data to data/wj-api.json
#  329/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322952
#          : Saved data to data/wj-api.json
#  330/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322951
#          : Saved data to data/wj-api.json
#  331/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322950
#          : Saved data to data/wj-api.json
#  332/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322949
#          : Saved data to data/wj-api.json
#  333/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322948
#          : Saved data to data/wj-api.json
#  334/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322947
#          : Saved data to data/wj-api.json
#  335/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322946
#          : Saved data to data/wj-api.json
#  336/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322945
#          : Saved data to data/wj-api.json
#  337/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322944
#          : Saved data to data/wj-api.json
#  338/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322943
#          : Saved data to data/wj-api.json
#  339/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322942
#          : Saved data to data/wj-api.json
#  340/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322941
#          : Saved data to data/wj-api.json
#  341/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322940
#          : Saved data to data/wj-api.json
#  342/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322939
#          : Saved data to data/wj-api.json
#  343/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322938
#          : Saved data to data/wj-api.json
#  344/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322937
#          : Saved data to data/wj-api.json
#  345/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322936
#          : Saved data to data/wj-api.json
#  346/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322935
#          : Saved data to data/wj-api.json
#  347/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322934
#          : Saved data to data/wj-api.json
#  348/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322933
#          : Saved data to data/wj-api.json
#  349/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322932
#          : Saved data to data/wj-api.json
#  350/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322931
#          : Saved data to data/wj-api.json
#  351/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322930
#          : Saved data to data/wj-api.json
#  352/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322929
#          : Saved data to data/wj-api.json
#  353/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322928
#          : Saved data to data/wj-api.json
#  354/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322927
#          : Saved data to data/wj-api.json
# ...
#          : Saved data to data/wj-api.json
#  368/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322912
#          : Saved data to data/wj-api.json
#  369/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322911
#          : Saved data to data/wj-api.json
#  370/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322910
#          : Saved data to data/wj-api.json
#  371/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322909
#          : Saved data to data/wj-api.json
#  372/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322908
#          : Saved data to data/wj-api.json
#  373/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322907
#          : Saved data to data/wj-api.json
#  374/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322906
#          : Saved data to data/wj-api.json
#  375/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322905
#          : Saved data to data/wj-api.json
#  376/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322904
#          : Saved data to data/wj-api.json
#  377/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322903
#          : Saved data to data/wj-api.json
#  378/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322902
#          : Saved data to data/wj-api.json
#  379/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322901
#          : Saved data to data/wj-api.json
#  380/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322900
#          : Saved data to data/wj-api.json
#  381/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322899
#          : Saved data to data/wj-api.json
#  382/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322898
#          : Saved data to data/wj-api.json
#  383/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322897
#          : Saved data to data/wj-api.json
#  384/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322896
#          : Saved data to data/wj-api.json
#  385/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322895
#          : Saved data to data/wj-api.json
#  386/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322894
#          : Saved data to data/wj-api.json
#  387/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322893
#          : Saved data to data/wj-api.json
#  388/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322892
#          : Saved data to data/wj-api.json
#  389/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322891
#          : Saved data to data/wj-api.json
#  390/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322890
#          : Saved data to data/wj-api.json
#  391/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322889
#          : Saved data to data/wj-api.json
#  392/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322888
#          : Saved data to data/wj-api.json
#  393/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322887
#          : Saved data to data/wj-api.json
#  394/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322886
#          : Saved data to data/wj-api.json
#  395/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322885
#          : Saved data to data/wj-api.json
#  396/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322884
#          : Saved data to data/wj-api.json
#  397/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322883
#          : Saved data to data/wj-api.json
#  398/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322882
#          : Saved data to data/wj-api.json
#  399/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322881
#          : Saved data to data/wj-api.json
#  400/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322880
#          : Saved data to data/wj-api.json
#  401/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322879
#          : Saved data to data/wj-api.json
#  402/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322878
#          : Saved data to data/wj-api.json
#  403/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322877
#          : Saved data to data/wj-api.json
#  404/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322876
#          : Saved data to data/wj-api.json
#  405/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322875
#          : Saved data to data/wj-api.json
#  406/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322874
#          : Saved data to data/wj-api.json
#  407/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322873
#          : Saved data to data/wj-api.json
#  408/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322872
#          : Saved data to data/wj-api.json
#  409/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322871
#          : Saved data to data/wj-api.json
#  410/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322870
#          : Saved data to data/wj-api.json
#  411/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322869
#          : Saved data to data/wj-api.json
#  412/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322868
#          : Saved data to data/wj-api.json
#  413/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322867
#          : Saved data to data/wj-api.json
#  414/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322866
#          : Saved data to data/wj-api.json
#  415/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322865
#          : Saved data to data/wj-api.json
#  416/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322864
#          : Saved data to data/wj-api.json
#  417/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322863
#          : Saved data to data/wj-api.json
#  418/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322862
#          : Saved data to data/wj-api.json
#  419/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322861
#          : Saved data to data/wj-api.json
#  420/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322860
#          : Saved data to data/wj-api.json
#  421/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322859
#          : Saved data to data/wj-api.json
#  422/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322858
#          : Saved data to data/wj-api.json
#  423/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322857
#          : Saved data to data/wj-api.json
#  424/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322856
#          : Saved data to data/wj-api.json
#  425/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322855
#          : Saved data to data/wj-api.json
#  426/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322854
#          : Saved data to data/wj-api.json
#  427/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322853
#          : Saved data to data/wj-api.json
#  428/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322852
#          : Saved data to data/wj-api.json
#  429/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322851
#          : Saved data to data/wj-api.json
#  430/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322850
#          : Saved data to data/wj-api.json
#  431/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322849
#          : Saved data to data/wj-api.json
#  432/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322848
#          : Saved data to data/wj-api.json
#  433/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322847
#          : Saved data to data/wj-api.json
#  434/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322846
#          : Saved data to data/wj-api.json
#  435/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322845
#          : Saved data to data/wj-api.json
#  436/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322844
#          : Saved data to data/wj-api.json
#  437/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322843
#          : Saved data to data/wj-api.json
#  438/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322842
#          : Saved data to data/wj-api.json
#  439/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322841
#          : Saved data to data/wj-api.json
#  440/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322840
#          : Saved data to data/wj-api.json
#  441/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322839
#          : Saved data to data/wj-api.json
#  442/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322838
#          : Saved data to data/wj-api.json
#  443/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322837
#          : Saved data to data/wj-api.json
#  444/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322836
#          : Saved data to data/wj-api.json
#  445/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322835
#          : Saved data to data/wj-api.json
#  446/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322834
#          : Saved data to data/wj-api.json
#  447/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322833
#          : Saved data to data/wj-api.json
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in connect(self)
#    1252
# -> 1253             super().connect()
#    1254
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in connect(self)
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     693     err = None
# --> 694     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     695         af, socktype, proto, canonname, sa = res
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     732     addrlist = []
# --> 733     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     734         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-11-88a1dc18ef3b> in <module>()
# ----> 1 save_data(magazines)
#
# <ipython-input-10-3012bd82dc77> in save_data(magazines, offset, file_name)
#      17         for m, magazine in enumerate(magazines[offset:]):
#      18             response = urllib.request.urlopen(url + str(magazine['id']),
# ---> 19                                               timeout=30)
#      20             content = json.loads(response.read().decode('utf8'))
#      21
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in https_open(self, req)
#    1295         def https_open(self, req):
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#    1299         https_request = AbstractHTTPHandler.do_request_
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
# -> 1256                 raise URLError(err)
#    1257             r = h.getresponse()
#    1258         except:
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>

# %% [markdown]
# タイムアウトした場合は，`offset`を利用して再開します．例えば，`447/2320`でタイムアウトした場合は，`save_data(offset=448)`を実行します．

# %%
save_data(magazines, offset=448)
# Out:
#  448/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322832
#          : Saved data to data/wj-api.json
#  449/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322831
#          : Saved data to data/wj-api.json
#  450/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322830
#          : Saved data to data/wj-api.json
#  451/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322829
#          : Saved data to data/wj-api.json
#  452/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322828
#          : Saved data to data/wj-api.json
#  453/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322827
#          : Saved data to data/wj-api.json
#  454/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322826
#          : Saved data to data/wj-api.json
#  455/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322825
#          : Saved data to data/wj-api.json
#  456/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322824
#          : Saved data to data/wj-api.json
#  457/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322823
#          : Saved data to data/wj-api.json
#  458/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322822
#          : Saved data to data/wj-api.json
#  459/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322821
#          : Saved data to data/wj-api.json
#  460/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322820
#          : Saved data to data/wj-api.json
#  461/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322819
#          : Saved data to data/wj-api.json
#  462/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322818
#          : Saved data to data/wj-api.json
#  463/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322817
#          : Saved data to data/wj-api.json
#  464/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322816
#          : Saved data to data/wj-api.json
#  465/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322815
#          : Saved data to data/wj-api.json
#  466/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322814
#          : Saved data to data/wj-api.json
#  467/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322813
#          : Saved data to data/wj-api.json
#  468/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322812
#          : Saved data to data/wj-api.json
#  469/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322811
#          : Saved data to data/wj-api.json
#  470/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322810
#          : Saved data to data/wj-api.json
#  471/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322809
#          : Saved data to data/wj-api.json
#  472/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322808
#          : Saved data to data/wj-api.json
#  473/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322807
#          : Saved data to data/wj-api.json
#  474/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322806
#          : Saved data to data/wj-api.json
#  475/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322805
#          : Saved data to data/wj-api.json
#  476/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322804
#          : Saved data to data/wj-api.json
#  477/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322803
#          : Saved data to data/wj-api.json
#  478/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322802
#          : Saved data to data/wj-api.json
#  479/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322801
#          : Saved data to data/wj-api.json
#  480/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322800
#          : Saved data to data/wj-api.json
#  481/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322799
#          : Saved data to data/wj-api.json
#  482/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322798
#          : Saved data to data/wj-api.json
#  483/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322797
#          : Saved data to data/wj-api.json
#  484/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322796
#          : Saved data to data/wj-api.json
#  485/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322795
#          : Saved data to data/wj-api.json
#  486/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322794
#          : Saved data to data/wj-api.json
#  487/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322793
#          : Saved data to data/wj-api.json
#  488/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322792
#          : Saved data to data/wj-api.json
#  489/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322791
#          : Saved data to data/wj-api.json
#  490/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322790
#          : Saved data to data/wj-api.json
#  491/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322789
#          : Saved data to data/wj-api.json
#  492/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322788
#          : Saved data to data/wj-api.json
#  493/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322787
#          : Saved data to data/wj-api.json
#  494/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322786
#          : Saved data to data/wj-api.json
#  495/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322785
#          : Saved data to data/wj-api.json
#  496/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322784
#          : Saved data to data/wj-api.json
#  497/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322783
#          : Saved data to data/wj-api.json
#  498/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322782
#          : Saved data to data/wj-api.json
#  499/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322781
#          : Saved data to data/wj-api.json
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in connect(self)
#    1252
# -> 1253             super().connect()
#    1254
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in connect(self)
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     693     err = None
# --> 694     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     695         af, socktype, proto, canonname, sa = res
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     732     addrlist = []
# --> 733     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     734         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-12-247a71dc96c2> in <module>()
# ----> 1 save_data(magazines, offset=448)
#
# <ipython-input-10-3012bd82dc77> in save_data(magazines, offset, file_name)
#      17         for m, magazine in enumerate(magazines[offset:]):
#      18             response = urllib.request.urlopen(url + str(magazine['id']),
# ---> 19                                               timeout=30)
#      20             content = json.loads(response.read().decode('utf8'))
#      21
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in https_open(self, req)
#    1295         def https_open(self, req):
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#    1299         https_request = AbstractHTTPHandler.do_request_
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
# -> 1256                 raise URLError(err)
#    1257             r = h.getresponse()
#    1258         except:
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>

# %%
save_data(magazines, offset=500)
# Out:
#  500/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322780
#          : Saved data to data/wj-api.json
#  501/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322779
#          : Saved data to data/wj-api.json
#  502/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322778
#          : Saved data to data/wj-api.json
#  503/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322777
#          : Saved data to data/wj-api.json
#  504/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322776
#          : Saved data to data/wj-api.json
#  505/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322775
#          : Saved data to data/wj-api.json
#  506/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322774
#          : Saved data to data/wj-api.json
#  507/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322773
#          : Saved data to data/wj-api.json
#  508/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322771
#          : Saved data to data/wj-api.json
#  509/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322770
#          : Saved data to data/wj-api.json
#  510/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322769
#          : Saved data to data/wj-api.json
#  511/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322768
#          : Saved data to data/wj-api.json
#  512/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322767
#          : Saved data to data/wj-api.json
#  513/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322766
#          : Saved data to data/wj-api.json
#  514/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322765
#          : Saved data to data/wj-api.json
#  515/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322764
#          : Saved data to data/wj-api.json
#  516/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322763
#          : Saved data to data/wj-api.json
#  517/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322762
#          : Saved data to data/wj-api.json
#  518/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322761
#          : Saved data to data/wj-api.json
#  519/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322760
#          : Saved data to data/wj-api.json
#  520/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322759
#          : Saved data to data/wj-api.json
#  521/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322758
#          : Saved data to data/wj-api.json
#  522/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322757
#          : Saved data to data/wj-api.json
#  523/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322756
#          : Saved data to data/wj-api.json
#  524/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322755
#          : Saved data to data/wj-api.json
#  525/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322754
#          : Saved data to data/wj-api.json
#  526/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322753
#          : Saved data to data/wj-api.json
#  527/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322752
#          : Saved data to data/wj-api.json
#  528/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322751
#          : Saved data to data/wj-api.json
#  529/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322750
#          : Saved data to data/wj-api.json
#  530/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322749
#          : Saved data to data/wj-api.json
#  531/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322748
#          : Saved data to data/wj-api.json
#  532/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322747
#          : Saved data to data/wj-api.json
#  533/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322746
#          : Saved data to data/wj-api.json
#  534/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322745
#          : Saved data to data/wj-api.json
#  535/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322744
#          : Saved data to data/wj-api.json
#  536/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322743
#          : Saved data to data/wj-api.json
#  537/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322742
#          : Saved data to data/wj-api.json
#  538/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322741
#          : Saved data to data/wj-api.json
#  539/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322740
#          : Saved data to data/wj-api.json
#  540/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322739
#          : Saved data to data/wj-api.json
#  541/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322738
#          : Saved data to data/wj-api.json
#  542/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322737
#          : Saved data to data/wj-api.json
#  543/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322736
#          : Saved data to data/wj-api.json
#  544/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322735
#          : Saved data to data/wj-api.json
#  545/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322734
#          : Saved data to data/wj-api.json
#  546/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322733
#          : Saved data to data/wj-api.json
#  547/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322732
#          : Saved data to data/wj-api.json
#  548/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322731
#          : Saved data to data/wj-api.json
#  549/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322730
#          : Saved data to data/wj-api.json
#  550/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322729
#          : Saved data to data/wj-api.json
#  551/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322728
#          : Saved data to data/wj-api.json
#  552/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322727
#          : Saved data to data/wj-api.json
#  553/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322726
#          : Saved data to data/wj-api.json
#  554/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322725
#          : Saved data to data/wj-api.json
#  555/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322724
#          : Saved data to data/wj-api.json
#  556/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322723
#          : Saved data to data/wj-api.json
#  557/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322722
#          : Saved data to data/wj-api.json
#  558/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322721
#          : Saved data to data/wj-api.json
#  559/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322720
#          : Saved data to data/wj-api.json
#  560/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322719
#          : Saved data to data/wj-api.json
#  561/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322718
#          : Saved data to data/wj-api.json
#  562/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322717
#          : Saved data to data/wj-api.json
#  563/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322716
#          : Saved data to data/wj-api.json
#  564/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322715
#          : Saved data to data/wj-api.json
#  565/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322714
#          : Saved data to data/wj-api.json
#  566/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322713
#          : Saved data to data/wj-api.json
#  567/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322712
#          : Saved data to data/wj-api.json
#  568/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322711
#          : Saved data to data/wj-api.json
#  569/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322710
#          : Saved data to data/wj-api.json
#  570/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322709
#          : Saved data to data/wj-api.json
#  571/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322708
#          : Saved data to data/wj-api.json
#  572/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322707
#          : Saved data to data/wj-api.json
#  573/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322706
#          : Saved data to data/wj-api.json
#  574/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322705
#          : Saved data to data/wj-api.json
#  575/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322704
#          : Saved data to data/wj-api.json
#  576/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322703
#          : Saved data to data/wj-api.json
#  577/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322702
#          : Saved data to data/wj-api.json
#  578/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322701
#          : Saved data to data/wj-api.json
#  579/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322700
#          : Saved data to data/wj-api.json
#  580/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322699
#          : Saved data to data/wj-api.json
#  581/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322698
#          : Saved data to data/wj-api.json
#  582/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322697
#          : Saved data to data/wj-api.json
#  583/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322696
#          : Saved data to data/wj-api.json
#  584/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322695
#          : Saved data to data/wj-api.json
#  585/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322694
#          : Saved data to data/wj-api.json
#  586/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322693
#          : Saved data to data/wj-api.json
#  587/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322692
#          : Saved data to data/wj-api.json
#  588/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322691
#          : Saved data to data/wj-api.json
#  589/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322651
#          : Saved data to data/wj-api.json
#  590/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322690
#          : Saved data to data/wj-api.json
#  591/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322689
#          : Saved data to data/wj-api.json
#  592/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322688
#          : Saved data to data/wj-api.json
#  593/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322687
#          : Saved data to data/wj-api.json
#  594/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322686
#          : Saved data to data/wj-api.json
#  595/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322685
#          : Saved data to data/wj-api.json
#  596/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322684
#          : Saved data to data/wj-api.json
#  597/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322683
#          : Saved data to data/wj-api.json
#  598/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322682
#          : Saved data to data/wj-api.json
#  599/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322681
#          : Saved data to data/wj-api.json
#  600/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322680
#          : Saved data to data/wj-api.json
#  601/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322679
#          : Saved data to data/wj-api.json
#  602/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322678
#          : Saved data to data/wj-api.json
#  603/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322677
#          : Saved data to data/wj-api.json
#  604/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322676
#          : Saved data to data/wj-api.json
#  605/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322675
#          : Saved data to data/wj-api.json
#  606/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322674
#          : Saved data to data/wj-api.json
#  607/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322673
#          : Saved data to data/wj-api.json
#  608/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322672
#          : Saved data to data/wj-api.json
#  609/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322671
#          : Saved data to data/wj-api.json
#  610/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322670
#          : Saved data to data/wj-api.json
#  611/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322669
#          : Saved data to data/wj-api.json
#  612/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322668
#          : Saved data to data/wj-api.json
#  613/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322667
#          : Saved data to data/wj-api.json
#  614/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322665
#          : Saved data to data/wj-api.json
#  615/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322664
#          : Saved data to data/wj-api.json
#  616/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322663
#          : Saved data to data/wj-api.json
#  617/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322662
#          : Saved data to data/wj-api.json
#  618/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322661
#          : Saved data to data/wj-api.json
#  619/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322660
#          : Saved data to data/wj-api.json
#  620/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322659
#          : Saved data to data/wj-api.json
#  621/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322658
#          : Saved data to data/wj-api.json
#  622/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322657
#          : Saved data to data/wj-api.json
#  623/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322656
#          : Saved data to data/wj-api.json
#  624/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322655
#          : Saved data to data/wj-api.json
#  625/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322654
#          : Saved data to data/wj-api.json
#  626/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322653
#          : Saved data to data/wj-api.json
#  627/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322652
#          : Saved data to data/wj-api.json
#  628/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322650
#          : Saved data to data/wj-api.json
#  629/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322649
#          : Saved data to data/wj-api.json
#  630/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322648
#          : Saved data to data/wj-api.json
#  631/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322647
#          : Saved data to data/wj-api.json
#  632/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322646
#          : Saved data to data/wj-api.json
#  633/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322645
#          : Saved data to data/wj-api.json
#  634/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322644
#          : Saved data to data/wj-api.json
#  635/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322643
#          : Saved data to data/wj-api.json
#  636/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322642
#          : Saved data to data/wj-api.json
#  637/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322641
#          : Saved data to data/wj-api.json
#  638/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322640
#          : Saved data to data/wj-api.json
#  639/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322639
#          : Saved data to data/wj-api.json
#  640/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322638
#          : Saved data to data/wj-api.json
#  641/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322637
#          : Saved data to data/wj-api.json
#  642/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322636
#          : Saved data to data/wj-api.json
#  643/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322635
#          : Saved data to data/wj-api.json
#  644/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322634
#          : Saved data to data/wj-api.json
#  645/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322633
#          : Saved data to data/wj-api.json
#  646/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322632
#          : Saved data to data/wj-api.json
#  647/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322631
#          : Saved data to data/wj-api.json
#  648/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322630
#          : Saved data to data/wj-api.json
#  649/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322629
#          : Saved data to data/wj-api.json
#  650/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322628
#          : Saved data to data/wj-api.json
#  651/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322627
#          : Saved data to data/wj-api.json
#  652/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322626
#          : Saved data to data/wj-api.json
#  653/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322625
#          : Saved data to data/wj-api.json
#  654/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322624
#          : Saved data to data/wj-api.json
#  655/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322623
#          : Saved data to data/wj-api.json
#  656/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322622
#          : Saved data to data/wj-api.json
#  657/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322621
#          : Saved data to data/wj-api.json
#  658/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322620
#          : Saved data to data/wj-api.json
#  659/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322619
#          : Saved data to data/wj-api.json
#  660/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322618
#          : Saved data to data/wj-api.json
#  661/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322617
#          : Saved data to data/wj-api.json
#  662/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322616
#          : Saved data to data/wj-api.json
#  663/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322615
#          : Saved data to data/wj-api.json
#  664/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322614
#          : Saved data to data/wj-api.json
#  665/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321170
#          : Saved data to data/wj-api.json
#  666/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322579
#          : Saved data to data/wj-api.json
#  667/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322613
#          : Saved data to data/wj-api.json
#  668/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322612
#          : Saved data to data/wj-api.json
#  669/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322611
#          : Saved data to data/wj-api.json
#  670/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322610
#          : Saved data to data/wj-api.json
#  671/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322609
#          : Saved data to data/wj-api.json
#  672/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322608
#          : Saved data to data/wj-api.json
#  673/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322607
#          : Saved data to data/wj-api.json
#  674/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322606
#          : Saved data to data/wj-api.json
#  675/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322605
#          : Saved data to data/wj-api.json
#  676/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322604
#          : Saved data to data/wj-api.json
#  677/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322603
#          : Saved data to data/wj-api.json
#  678/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322602
#          : Saved data to data/wj-api.json
#  679/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322601
#          : Saved data to data/wj-api.json
#  680/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322600
#          : Saved data to data/wj-api.json
#  681/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322599
#          : Saved data to data/wj-api.json
#  682/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322598
#          : Saved data to data/wj-api.json
#  683/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322597
#          : Saved data to data/wj-api.json
#  684/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322596
#          : Saved data to data/wj-api.json
#  685/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322595
#          : Saved data to data/wj-api.json
#  686/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322594
#          : Saved data to data/wj-api.json
#  687/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322593
#          : Saved data to data/wj-api.json
#  688/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322592
#          : Saved data to data/wj-api.json
#  689/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322591
#          : Saved data to data/wj-api.json
#  690/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322590
#          : Saved data to data/wj-api.json
#  691/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322589
#          : Saved data to data/wj-api.json
#  692/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322588
#          : Saved data to data/wj-api.json
#  693/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322587
#          : Saved data to data/wj-api.json
#  694/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322586
#          : Saved data to data/wj-api.json
#  695/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322585
#          : Saved data to data/wj-api.json
#  696/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322584
#          : Saved data to data/wj-api.json
#  697/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322583
#          : Saved data to data/wj-api.json
#  698/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322582
#          : Saved data to data/wj-api.json
#  699/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322581
#          : Saved data to data/wj-api.json
#  700/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322580
#          : Saved data to data/wj-api.json
#  701/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322578
#          : Saved data to data/wj-api.json
#  702/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322577
#          : Saved data to data/wj-api.json
#  703/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322576
#          : Saved data to data/wj-api.json
#  704/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322575
#          : Saved data to data/wj-api.json
#  705/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322574
#          : Saved data to data/wj-api.json
#  706/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322573
#          : Saved data to data/wj-api.json
#  707/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322572
#          : Saved data to data/wj-api.json
#  708/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322571
#          : Saved data to data/wj-api.json
#  709/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322570
#          : Saved data to data/wj-api.json
#  710/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322569
#          : Saved data to data/wj-api.json
#  711/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322568
#          : Saved data to data/wj-api.json
#  712/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322567
#          : Saved data to data/wj-api.json
#  713/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322566
#          : Saved data to data/wj-api.json
#  714/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322564
#          : Saved data to data/wj-api.json
#  715/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322563
#          : Saved data to data/wj-api.json
#  716/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322562
#          : Saved data to data/wj-api.json
#  717/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322561
#          : Saved data to data/wj-api.json
#  718/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322560
#          : Saved data to data/wj-api.json
#  719/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322559
#          : Saved data to data/wj-api.json
#  720/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322558
#          : Saved data to data/wj-api.json
#  721/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322557
#          : Saved data to data/wj-api.json
#  722/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322556
#          : Saved data to data/wj-api.json
#  723/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322555
#          : Saved data to data/wj-api.json
#  724/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322554
#          : Saved data to data/wj-api.json
#  725/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322553
#          : Saved data to data/wj-api.json
#  726/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322552
#          : Saved data to data/wj-api.json
#  727/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322551
#          : Saved data to data/wj-api.json
#  728/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322550
#          : Saved data to data/wj-api.json
#  729/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322549
#          : Saved data to data/wj-api.json
#  730/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322548
#          : Saved data to data/wj-api.json
#  731/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322547
#          : Saved data to data/wj-api.json
#  732/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322546
#          : Saved data to data/wj-api.json
#  733/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322545
#          : Saved data to data/wj-api.json
#  734/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322544
#          : Saved data to data/wj-api.json
#  735/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322543
#          : Saved data to data/wj-api.json
#  736/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322542
#          : Saved data to data/wj-api.json
#  737/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322541
#          : Saved data to data/wj-api.json
#  738/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322540
#          : Saved data to data/wj-api.json
#  739/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322539
#          : Saved data to data/wj-api.json
#  740/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322538
#          : Saved data to data/wj-api.json
#  741/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322537
#          : Saved data to data/wj-api.json
#  742/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322536
#          : Saved data to data/wj-api.json
#  743/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322535
#          : Saved data to data/wj-api.json
#  744/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322534
#          : Saved data to data/wj-api.json
#  745/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322533
#          : Saved data to data/wj-api.json
#  746/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322532
#          : Saved data to data/wj-api.json
#  747/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322531
#          : Saved data to data/wj-api.json
#  748/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322530
#          : Saved data to data/wj-api.json
#  749/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322529
#          : Saved data to data/wj-api.json
#  750/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322528
#          : Saved data to data/wj-api.json
#  751/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322527
#          : Saved data to data/wj-api.json
#  752/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322526
#          : Saved data to data/wj-api.json
#  753/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322525
#          : Saved data to data/wj-api.json
#  754/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322524
#          : Saved data to data/wj-api.json
#  755/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322523
#          : Saved data to data/wj-api.json
#  756/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322522
#          : Saved data to data/wj-api.json
#  757/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322521
#          : Saved data to data/wj-api.json
#  758/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322520
#          : Saved data to data/wj-api.json
#  759/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322519
#          : Saved data to data/wj-api.json
#  760/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322518
#          : Saved data to data/wj-api.json
#  761/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322517
#          : Saved data to data/wj-api.json
#  762/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322516
#          : Saved data to data/wj-api.json
#  763/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322515
#          : Saved data to data/wj-api.json
#  764/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322513
#          : Saved data to data/wj-api.json
#  765/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322512
#          : Saved data to data/wj-api.json
#  766/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322511
#          : Saved data to data/wj-api.json
#  767/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322510
#          : Saved data to data/wj-api.json
#  768/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322509
#          : Saved data to data/wj-api.json
#  769/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322508
#          : Saved data to data/wj-api.json
#  770/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322507
#          : Saved data to data/wj-api.json
#  771/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322506
#          : Saved data to data/wj-api.json
#  772/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322505
#          : Saved data to data/wj-api.json
#  773/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322504
#          : Saved data to data/wj-api.json
#  774/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322503
#          : Saved data to data/wj-api.json
#  775/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322502
#          : Saved data to data/wj-api.json
#  776/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322501
#          : Saved data to data/wj-api.json
#  777/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322500
#          : Saved data to data/wj-api.json
#  778/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322499
#          : Saved data to data/wj-api.json
#  779/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322498
#          : Saved data to data/wj-api.json
#  780/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322497
#          : Saved data to data/wj-api.json
#  781/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322496
#          : Saved data to data/wj-api.json
#  782/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322495
#          : Saved data to data/wj-api.json
#  783/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322494
#          : Saved data to data/wj-api.json
#  784/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322493
#          : Saved data to data/wj-api.json
#  785/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322492
#          : Saved data to data/wj-api.json
#  786/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322491
#          : Saved data to data/wj-api.json
#  787/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322490
#          : Saved data to data/wj-api.json
#  788/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322489
#          : Saved data to data/wj-api.json
#  789/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322488
#          : Saved data to data/wj-api.json
#  790/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322487
#          : Saved data to data/wj-api.json
#  791/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322486
#          : Saved data to data/wj-api.json
#  792/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322485
#          : Saved data to data/wj-api.json
#  793/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322484
#          : Saved data to data/wj-api.json
#  794/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322483
#          : Saved data to data/wj-api.json
#  795/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322482
#          : Saved data to data/wj-api.json
#  796/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322480
#          : Saved data to data/wj-api.json
#  797/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322479
#          : Saved data to data/wj-api.json
#  798/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322478
#          : Saved data to data/wj-api.json
#  799/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322477
#          : Saved data to data/wj-api.json
#  800/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322476
#          : Saved data to data/wj-api.json
#  801/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322475
#          : Saved data to data/wj-api.json
#  802/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322474
#          : Saved data to data/wj-api.json
#  803/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322473
#          : Saved data to data/wj-api.json
#  804/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322472
#          : Saved data to data/wj-api.json
#  805/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322471
#          : Saved data to data/wj-api.json
#  806/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322470
#          : Saved data to data/wj-api.json
#  807/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322469
#          : Saved data to data/wj-api.json
#  808/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322468
#          : Saved data to data/wj-api.json
#  809/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322467
#          : Saved data to data/wj-api.json
#  810/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322466
#          : Saved data to data/wj-api.json
#  811/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322465
#          : Saved data to data/wj-api.json
#  812/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322464
#          : Saved data to data/wj-api.json
#  813/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322463
#          : Saved data to data/wj-api.json
#  814/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322461
#          : Saved data to data/wj-api.json
#  815/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322460
#          : Saved data to data/wj-api.json
#  816/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322459
#          : Saved data to data/wj-api.json
#  817/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322458
#          : Saved data to data/wj-api.json
#  818/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322457
#          : Saved data to data/wj-api.json
#  819/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322456
#          : Saved data to data/wj-api.json
#  820/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322455
#          : Saved data to data/wj-api.json
#  821/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322454
#          : Saved data to data/wj-api.json
#  822/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322453
#          : Saved data to data/wj-api.json
#  823/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322452
#          : Saved data to data/wj-api.json
#  824/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322451
#          : Saved data to data/wj-api.json
#  825/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322450
#          : Saved data to data/wj-api.json
#  826/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322449
#          : Saved data to data/wj-api.json
#  827/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322448
#          : Saved data to data/wj-api.json
#  828/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322447
#          : Saved data to data/wj-api.json
#  829/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322446
#          : Saved data to data/wj-api.json
#  830/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322445
#          : Saved data to data/wj-api.json
#  831/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322444
#          : Saved data to data/wj-api.json
#  832/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322443
#          : Saved data to data/wj-api.json
#  833/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322442
#          : Saved data to data/wj-api.json
#  834/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322441
#          : Saved data to data/wj-api.json
#  835/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322440
#          : Saved data to data/wj-api.json
#  836/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322439
#          : Saved data to data/wj-api.json
#  837/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322438
#          : Saved data to data/wj-api.json
#  838/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322437
#          : Saved data to data/wj-api.json
#  839/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322436
#          : Saved data to data/wj-api.json
#  840/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322435
#          : Saved data to data/wj-api.json
#  841/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322434
#          : Saved data to data/wj-api.json
#  842/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322433
#          : Saved data to data/wj-api.json
#  843/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322432
#          : Saved data to data/wj-api.json
#  844/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322431
#          : Saved data to data/wj-api.json
#  845/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322430
#          : Saved data to data/wj-api.json
#  846/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322429
#          : Saved data to data/wj-api.json
#  847/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322427
#          : Saved data to data/wj-api.json
#  848/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322426
#          : Saved data to data/wj-api.json
#  849/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322425
#          : Saved data to data/wj-api.json
#  850/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322424
#          : Saved data to data/wj-api.json
#  851/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322423
#          : Saved data to data/wj-api.json
#  852/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322422
#          : Saved data to data/wj-api.json
#  853/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322421
#          : Saved data to data/wj-api.json
#  854/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322420
#          : Saved data to data/wj-api.json
# ...
#          : Saved data to data/wj-api.json
# 1189/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322080
#          : Saved data to data/wj-api.json
# 1190/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322079
#          : Saved data to data/wj-api.json
# 1191/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322078
#          : Saved data to data/wj-api.json
# 1192/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322077
#          : Saved data to data/wj-api.json
# 1193/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322076
#          : Saved data to data/wj-api.json
# 1194/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322075
#          : Saved data to data/wj-api.json
# 1195/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322074
#          : Saved data to data/wj-api.json
# 1196/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322073
#          : Saved data to data/wj-api.json
# 1197/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322072
#          : Saved data to data/wj-api.json
# 1198/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322071
#          : Saved data to data/wj-api.json
# 1199/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322070
#          : Saved data to data/wj-api.json
# 1200/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322069
#          : Saved data to data/wj-api.json
# 1201/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322068
#          : Saved data to data/wj-api.json
# 1202/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322067
#          : Saved data to data/wj-api.json
# 1203/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322066
#          : Saved data to data/wj-api.json
# 1204/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322065
#          : Saved data to data/wj-api.json
# 1205/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322064
#          : Saved data to data/wj-api.json
# 1206/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322063
#          : Saved data to data/wj-api.json
# 1207/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322062
#          : Saved data to data/wj-api.json
# 1208/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322061
#          : Saved data to data/wj-api.json
# 1209/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322060
#          : Saved data to data/wj-api.json
# 1210/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322059
#          : Saved data to data/wj-api.json
# 1211/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322058
#          : Saved data to data/wj-api.json
# 1212/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322057
#          : Saved data to data/wj-api.json
# 1213/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322055
#          : Saved data to data/wj-api.json
# 1214/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322051
#          : Saved data to data/wj-api.json
# 1215/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322050
#          : Saved data to data/wj-api.json
# 1216/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322049
#          : Saved data to data/wj-api.json
# 1217/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322048
#          : Saved data to data/wj-api.json
# 1218/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322047
#          : Saved data to data/wj-api.json
# 1219/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322046
#          : Saved data to data/wj-api.json
# 1220/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322045
#          : Saved data to data/wj-api.json
# 1221/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322044
#          : Saved data to data/wj-api.json
# 1222/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322043
#          : Saved data to data/wj-api.json
# 1223/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322042
#          : Saved data to data/wj-api.json
# 1224/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322041
#          : Saved data to data/wj-api.json
# 1225/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322040
#          : Saved data to data/wj-api.json
# 1226/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322039
#          : Saved data to data/wj-api.json
# 1227/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322038
#          : Saved data to data/wj-api.json
# 1228/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322037
#          : Saved data to data/wj-api.json
# 1229/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322036
#          : Saved data to data/wj-api.json
# 1230/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322035
#          : Saved data to data/wj-api.json
# 1231/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322034
#          : Saved data to data/wj-api.json
# 1232/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322033
#          : Saved data to data/wj-api.json
# 1233/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322032
#          : Saved data to data/wj-api.json
# 1234/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322031
#          : Saved data to data/wj-api.json
# 1235/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322030
#          : Saved data to data/wj-api.json
# 1236/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322029
#          : Saved data to data/wj-api.json
# 1237/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322028
#          : Saved data to data/wj-api.json
# 1238/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322027
#          : Saved data to data/wj-api.json
# 1239/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322026
#          : Saved data to data/wj-api.json
# 1240/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322025
#          : Saved data to data/wj-api.json
# 1241/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322024
#          : Saved data to data/wj-api.json
# 1242/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=476128
#          : Saved data to data/wj-api.json
# 1243/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322023
#          : Saved data to data/wj-api.json
# 1244/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322022
#          : Saved data to data/wj-api.json
# 1245/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322021
#          : Saved data to data/wj-api.json
# 1246/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322020
#          : Saved data to data/wj-api.json
# 1247/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322019
#          : Saved data to data/wj-api.json
# 1248/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322018
#          : Saved data to data/wj-api.json
# 1249/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322017
#          : Saved data to data/wj-api.json
# 1250/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322016
#          : Saved data to data/wj-api.json
# 1251/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322015
#          : Saved data to data/wj-api.json
# 1252/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322014
#          : Saved data to data/wj-api.json
# 1253/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322013
#          : Saved data to data/wj-api.json
# 1254/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322012
#          : Saved data to data/wj-api.json
# 1255/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322011
#          : Saved data to data/wj-api.json
# 1256/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322010
#          : Saved data to data/wj-api.json
# 1257/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322009
#          : Saved data to data/wj-api.json
# 1258/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322008
#          : Saved data to data/wj-api.json
# 1259/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322007
#          : Saved data to data/wj-api.json
# 1260/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322006
#          : Saved data to data/wj-api.json
# 1261/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322005
#          : Saved data to data/wj-api.json
# 1262/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322003
#          : Saved data to data/wj-api.json
# 1263/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322002
#          : Saved data to data/wj-api.json
# 1264/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322001
#          : Saved data to data/wj-api.json
# 1265/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=322000
#          : Saved data to data/wj-api.json
# 1266/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321999
#          : Saved data to data/wj-api.json
# 1267/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321998
#          : Saved data to data/wj-api.json
# 1268/2320: Extracted data from https://mediaarts-db.bunka.go.jp/mg/api/v1/magazine?id=321997
#          : Saved data to data/wj-api.json
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in connect(self)
#    1252
# -> 1253             super().connect()
#    1254
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/http/client.py in connect(self)
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     693     err = None
# --> 694     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     695         af, socktype, proto, canonname, sa = res
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     732     addrlist = []
# --> 733     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     734         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-13-e47f0794b62b> in <module>()
# ----> 1 save_data(magazines, offset=500)
#
# <ipython-input-10-3012bd82dc77> in save_data(magazines, offset, file_name)
#      17         for m, magazine in enumerate(magazines[offset:]):
#      18             response = urllib.request.urlopen(url + str(magazine['id']),
# ---> 19                                               timeout=30)
#      20             content = json.loads(response.read().decode('utf8'))
#      21
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in https_open(self, req)
#    1295         def https_open(self, req):
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#    1299         https_request = AbstractHTTPHandler.do_request_
#
# /home/ryoma/anaconda3/envs/comic/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
# -> 1256                 raise URLError(err)
#    1257             r = h.getresponse()
#    1258         except:
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>

# %% [markdown]
# 以下，確認用のコード．不要になったら消すこと．また，magazinesの抽出も関数化すること．

# %%
with open('data/wj-api.json', 'r', encoding='utf-8') as f:
    comics2 = json.load(f)
comics2
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-48-0ca616e547c7> in <module>()
#       1 with open('data/wj-api.json', 'r', encoding='utf-8') as f:
# ----> 2     comics2 = json.load(f)
#       3 comics2
#
# /home/ryoma/anaconda3/envs/tensorflow/lib/python3.5/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
# --> 268         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     269
#     270
#
# /home/ryoma/anaconda3/envs/tensorflow/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# /home/ryoma/anaconda3/envs/tensorflow/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /home/ryoma/anaconda3/envs/tensorflow/lib/python3.5/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 40701 column 1 (char 6764365)
